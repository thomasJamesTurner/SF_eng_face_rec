# %%
# !pip install pyngrok
# !pip install DeepFace
from deepface import DeepFace
from pyngrok import ngrok
from flask import Flask,Response,request,render_template
from google.colab import drive
import time,requests,subprocess,base64

drive.mount("/content/drive")

filepath = "/content/drive/MyDrive/Colab/attendance/"
ngrok.set_auth_token(ngrok_key)

app = Flask(__name__,template_folder= filepath+"templates",static_folder=filepath+"static")

def start_ngrok():
    ngrok_process = subprocess.Popen(['ngrok', 'http', '5000'])
    time.sleep(4)
    response = requests.get('http://localhost:4040/api/tunnels')
    tunnel_info = response.json()
    public_url = tunnel_info['tunnels'][0]['public_url']
    print(" * ngrok tunnel URL:", public_url)
    return public_url

upload_folder = "/content/drive/MyDrive/Colab/attendance"

app.config['UPLOAD'] = upload_folder

@app.route('/image', methods=['GET', 'POST'])

def upload_file():
    if request.method == 'POST':
        name = ""
        filename = str(time.time()) + ".jpeg"
        imagedata = request.data[23:]
        with open(filename, "wb") as img:
          img.write(base64.decodebytes(imagedata))
        search = DeepFace.find(img_path= filename, db_path= filepath + "/students", model_name= "ArcFace",  detector_backend = "retinaface", enforce_detection= False, anti_spoofing = True)
        #print(search[0]["identity"][0].split("/")[7])
        name = search[0]["identity"][0].split("/")[8]
    print(f"name:{name}")
    return ""


@app.route('/')
def index():
  return render_template('index.html')



if __name__ == '__main__':
    public_url = start_ngrok()
    app.run(port=5000)
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#  * ngrok tunnel URL: https://5ffe-35-237-18-5.ngrok-free.app
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [02/Dec/2024 16:08:56] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [02/Dec/2024 16:08:57] "GET /static/webcam.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [02/Dec/2024 16:08:57] "GET /favicon.ico HTTP/1.1" 404 -
# 24-12-02 16:09:06 - Found 0 newly added image(s), 0 removed image(s), 2 replaced image(s).
# Finding representations: 100%|██████████| 2/2 [00:15<00:00,  7.68s/it]
# ...
